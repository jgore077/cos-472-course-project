# %%
import pandas as pd

#Read dataset CSV
#train = pd.read_csv("C:/Users/Thad/Projects/cos-472-course-project/data/cleaned.csv")
train = pd.read_csv("C:/Users/Thad/Projects/cos-472-course-project/data/cleaned.csv")

# %%
#Split to x and y sets
x = train.drop(['sii'], axis=1)
x.info()
y = train['sii']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2736 entries, 0 to 2735
# Data columns (total 74 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Basic_Demos-Enroll_Season               2736 non-null   int64
#  1   Basic_Demos-Age                         2736 non-null   int64
#  2   Basic_Demos-Sex                         2736 non-null   int64
#  3   CGAS-Season                             2736 non-null   int64
#  4   CGAS-CGAS_Score                         2736 non-null   int64
#  5   Physical-Season                         2736 non-null   int64
#  6   Physical-BMI                            2736 non-null   int64
#  7   Physical-Height                         2736 non-null   int64
#  8   Physical-Weight                         2736 non-null   int64
#  9   Physical-Diastolic_BP                   2736 non-null   int64
#  10  Physical-HeartRate                      2736 non-null   int64
#  11  Physical-Systolic_BP                    2736 non-null   int64
#  12  Fitness_Endurance-Season                2736 non-null   int64
#  13  FGC-Season                              2736 non-null   int64
#  14  FGC-FGC_CU                              2736 non-null   int64
#  15  FGC-FGC_CU_Zone                         2736 non-null   int64
#  16  FGC-FGC_GSND                            2736 non-null   int64
#  17  FGC-FGC_GSND_Zone                       2736 non-null   int64
#  18  FGC-FGC_GSD                             2736 non-null   int64
#  19  FGC-FGC_GSD_Zone                        2736 non-null   int64
#  20  FGC-FGC_PU                              2736 non-null   int64
#  21  FGC-FGC_PU_Zone                         2736 non-null   int64
#  22  FGC-FGC_SRL                             2736 non-null   int64
#  23  FGC-FGC_SRL_Zone                        2736 non-null   int64
#  24  FGC-FGC_SRR                             2736 non-null   int64
#  25  FGC-FGC_SRR_Zone                        2736 non-null   int64
#  26  FGC-FGC_TL                              2736 non-null   int64
#  27  FGC-FGC_TL_Zone                         2736 non-null   int64
#  28  BIA-Season                              2736 non-null   int64
#  29  BIA-BIA_Activity_Level_num              2736 non-null   int64
#  30  BIA-BIA_BMC                             2736 non-null   int64
#  31  BIA-BIA_BMI                             2736 non-null   int64
#  32  BIA-BIA_BMR                             2736 non-null   int64
#  33  BIA-BIA_DEE                             2736 non-null   int64
#  34  BIA-BIA_ECW                             2736 non-null   int64
#  35  BIA-BIA_FFM                             2736 non-null   int64
#  36  BIA-BIA_FFMI                            2736 non-null   int64
#  37  BIA-BIA_FMI                             2736 non-null   int64
#  38  BIA-BIA_Fat                             2736 non-null   int64
#  39  BIA-BIA_Frame_num                       2736 non-null   int64
#  40  BIA-BIA_ICW                             2736 non-null   int64
#  41  BIA-BIA_LDM                             2736 non-null   int64
#  42  BIA-BIA_LST                             2736 non-null   int64
#  43  BIA-BIA_SMM                             2736 non-null   int64
#  44  BIA-BIA_TBW                             2736 non-null   int64
#  45  PAQ_C-Season                            2736 non-null   int64
#  46  PAQ_C-PAQ_C_Total                       2736 non-null   int64
#  47  PCIAT-Season                            2736 non-null   int64
#  48  PCIAT-PCIAT_01                          2736 non-null   int64
#  49  PCIAT-PCIAT_02                          2736 non-null   int64
#  50  PCIAT-PCIAT_03                          2736 non-null   int64
#  51  PCIAT-PCIAT_04                          2736 non-null   int64
#  52  PCIAT-PCIAT_05                          2736 non-null   int64
#  53  PCIAT-PCIAT_06                          2736 non-null   int64
#  54  PCIAT-PCIAT_07                          2736 non-null   int64
#  55  PCIAT-PCIAT_08                          2736 non-null   int64
#  56  PCIAT-PCIAT_09                          2736 non-null   int64
#  57  PCIAT-PCIAT_10                          2736 non-null   int64
#  58  PCIAT-PCIAT_11                          2736 non-null   int64
#  59  PCIAT-PCIAT_12                          2736 non-null   int64
#  60  PCIAT-PCIAT_13                          2736 non-null   int64
#  61  PCIAT-PCIAT_14                          2736 non-null   int64
#  62  PCIAT-PCIAT_15                          2736 non-null   int64
#  63  PCIAT-PCIAT_16                          2736 non-null   int64
#  64  PCIAT-PCIAT_17                          2736 non-null   int64
#  65  PCIAT-PCIAT_18                          2736 non-null   int64
#  66  PCIAT-PCIAT_19                          2736 non-null   int64
#  67  PCIAT-PCIAT_20                          2736 non-null   int64
#  68  PCIAT-PCIAT_Total                       2736 non-null   float64
#  69  SDS-Season                              2736 non-null   int64
#  70  SDS-SDS_Total_Raw                       2736 non-null   int64
#  71  SDS-SDS_Total_T                         2736 non-null   int64
#  72  PreInt_EduHx-Season                     2736 non-null   int64
#  73  PreInt_EduHx-computerinternet_hoursday  2736 non-null   int64
# dtypes: float64(1), int64(73)
# memory usage: 1.5 MB

# %%
from sklearn.model_selection import train_test_split

#Train/test splitting
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# creating a RF classifier
clf = RandomForestClassifier(n_estimators = 175, max_depth=8, max_features= 'log2')  
 
# Training the model
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, max_features='log2', n_estimators=175)

# %%
import matplotlib.pyplot as plt
from sklearn import tree

fn='data.feature_names'
cn='data.target_names'
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (10,4), dpi=800)
tree.plot_tree(clf.estimators_[0],
          
               filled = True);
fig.savefig('rf_individualtree.png')

# %%
import numpy as np

importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)

forest_importances = pd.Series(importances)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
#Confusion matrix
from sklearn import metrics

actual = np.random.binomial(1,.9,size = 1000)
predicted = np.random.binomial(1,.9,size = 1000)

pred = clf.predict(x_test)
confusion_matrix = metrics.confusion_matrix(y_test, pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1, 2, 3])

cm_display.plot()
plt.show()

# %%
from sklearn.metrics import f1_score
f1_score(y_test, pred, average=None)
# Out:
# array([0.99850969, 0.98496241, 0.95774648, 0.94117647])

# %%
import preprocess

test = pd.read_csv("C:/Users/Thad/Projects/cos-472-course-project/data/test.csv")

processed = preprocess.prepare_data(test, False)

pred = clf.predict(test)

#df = pd.DataFrame({'PassengerId' :test['PassengerId'], 'Survived' :pred})

#df.info()
#df.to_csv('results_ne175.csv', index=False)
# Out:
# Dropped 11 columns with >70% missing values: ['Physical-Waist_Circumference', 'Fitness_Endurance-Season', 'Fitness_Endurance-Max_Stage', 'Fitness_Endurance-Time_Mins', 'Fitness_Endurance-Time_Sec', 'FGC-FGC_GSND', 'FGC-FGC_GSND_Zone', 'FGC-FGC_GSD', 'FGC-FGC_GSD_Zone', 'PAQ_A-Season', 'PAQ_A-PAQ_A_Total']
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# c:\Users\Thad\Projects\cos-472-course-project\preprocess.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   numeric_mask = data[column].str.match(r'^-?\d*\.?\d*$').fillna(False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 7
#       3 test = pd.read_csv("C:/Users/Thad/Projects/cos-472-course-project/data/test.csv")
#       5 processed = preprocess.prepare_data(test, False)
# ----> 7 pred = clf.predict(test)
#
# File c:\Users\Thad\miniconda3\envs\COS472\Lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File c:\Users\Thad\miniconda3\envs\COS472\Lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\Thad\miniconda3\envs\COS472\Lib\site-packages\sklearn\ensemble\_forest.py:641, in BaseForest._validate_X_predict(self, X)
#     638 else:
#     639     force_all_finite = True
# --> 641 X = self._validate_data(
#     642     X,
#     643     dtype=DTYPE,
#     644     accept_sparse="csr",
#     645     reset=False,
#     646     force_all_finite=force_all_finite,
#     647 )
#     648 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     649     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\Thad\miniconda3\envs\COS472\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File c:\Users\Thad\miniconda3\envs\COS472\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - Fitness_Endurance-Max_Stage
# - Fitness_Endurance-Time_Mins
# - Fitness_Endurance-Time_Sec
# - PAQ_A-PAQ_A_Total
# - PAQ_A-Season
# - ...
# Feature names seen at fit time, yet now missing:
# - PCIAT-PCIAT_01
# - PCIAT-PCIAT_02
# - PCIAT-PCIAT_03
# - PCIAT-PCIAT_04
# - PCIAT-PCIAT_05
# - ...
